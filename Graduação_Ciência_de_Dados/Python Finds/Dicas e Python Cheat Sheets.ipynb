# %% [markdown]
# # Dicas de Python
# ---
# > Python Cheat Sheets:
# > ![image.png](attachment:image.png)
# > Fonte: [Post do Bruno Tojal no LinkedIn](https://www.linkedin.com/feed/update/urn:li:activity:7242874142339809280/)
# ---

# %% [markdown]
# ## Curoso Grátis de Python para Data Science - em inglês
# [Dataquest](https://app.dataquest.io/learning/path/data-analyst/v2-3)
#
# ---

# %% [markdown]
# ## Exercícios de Python
# [Hacking Science](https://www.hackinscience.org/exercises/import)
#
# ---
