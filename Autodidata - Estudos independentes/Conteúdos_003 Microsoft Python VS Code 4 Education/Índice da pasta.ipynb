# %% [markdown]
# # Conteúdos de Python da Microsoft for Education
#
# [Tutorial de Python](https://code.visualstudio.com/docs/python/python-tutorial)

# %%
print('Hello, world!')
# Out:
# Hello, world!
