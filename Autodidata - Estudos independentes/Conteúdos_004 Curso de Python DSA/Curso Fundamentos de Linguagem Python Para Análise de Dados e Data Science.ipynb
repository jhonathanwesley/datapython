# %% [markdown]
# # Fundamentos de Linguagem Python Para Análise de Dados e Data Science
# > DSA - Data Science Academy
#
# * [Curso](https://www.datascienceacademy.com.br/course/fundamentos-de-linguagem-python-para-analise-de-dados-e-data-science)

# %%
print("""D\nS\nA""")
# Out:
# D
# S
# A

# %%
for i in range(21):
    print(f'Capítulo {i} -')
# Out:
# Capítulo 0 -
# Capítulo 1 -
# Capítulo 2 -
# Capítulo 3 -
# Capítulo 4 -
# Capítulo 5 -
# Capítulo 6 -
# Capítulo 7 -
# Capítulo 8 -
# Capítulo 9 -
# Capítulo 10 -
# Capítulo 11 -
# Capítulo 12 -
# Capítulo 13 -
# Capítulo 14 -
# Capítulo 15 -
# Capítulo 16 -
# Capítulo 17 -
# Capítulo 18 -
# Capítulo 19 -
# Capítulo 20 -

# %% [markdown]
# 1. Nível Introdutório
#     - Capítulo 01 - Introdução
#     - Capítulo 02 - Primeiros passos com a Linguagem Python - Visão geral, Instalção e ChatGPT
#     - Capítulo 03 - Introdução á lógica de programação
#     - Capítulo 04 - Variáveis, Tipos e Estruturas de Dados
#     - Capítulo 05 - Loops, Condicionais, Métodos e Funções
#     - Capítulo 06 - Tratamento de Arquivos, Módulos, Pacotes e Funções Built-in
#     - Capítulo 07 - Projeto 1 e Avaliação 1
#
# 2. Nível Básico
#     - Capítulo 08 - Introdução à POO
#     - Capítulo 09 - Matemática e Manipulação de Matrizes com NumPy
#     - Capítulo 10 - Manipulação de Dados com Pandas
#     - Capítulo 11 - Visualização de Dados com Matplotlib e Seaborn
#     - Capítulo 12 - Análise de Dados com Python e Linguagem SQL
#     - Capítulo 13 - Projeto 2 e Avaliação 2
#
# 3. Nível Intermediário
#     - Capítulo 14 - Análise Estatística com Statsmodels
#     - Capítulo 15 - Análise de Séries Temporais em Python
#     - Capítulo 16 - Machine Learning com Scikit-Learn
#     - Capítulo 17 - Introdução a Deep Learning com TensorFlow
#     - Capítulo 18 - Aprendizado Por Reforço (Reinforcement Learning)
#     - Capítulo 19 - Projeto 3
#     - Capítulo 20 - Avaliação e Certificado de Conclusão
